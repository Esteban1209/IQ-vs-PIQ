# %% [markdown]
# #1. Importar librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_palette('colorblind')
sns.set(style="whitegrid")

# %% [markdown]
# #2. Carga y exploracion de datos

# %%
df = pd.read_csv('sample_data/brain_size.csv')

# %%
print(df.head(5))
# Out:
#       PIQ     IQ
# 0  1168.0  578.0
# 1  1134.0  545.0
# 2   946.0  472.0
# 3  1126.0  581.0
# 4  1001.0  522.0

# %%
print(df.describe())
# Out:
#                PIQ           IQ
# count  1500.000000  1500.000000
# mean   1006.147333   503.114667
# std     150.126721    77.027196
# min     438.000000   204.000000
# 25%     912.000000   450.000000
# 50%    1006.000000   504.000000
# 75%    1107.000000   553.000000
# max    1525.000000   790.000000

# %% [markdown]
# #3. Limpieza de datos

# %% [markdown]
# Validacion de datos

# %%
print(df.isnull().sum())
# Out:
# PIQ    0
# IQ     0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 45

# %%
print(df.dtypes)
# Out:
# PIQ    float64
# IQ     float64
# dtype: object

# %% [markdown]
# Limpieza

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
print("Valores nulos: ", df.isnull().sum())
# Out:
# Valores nulos:  PIQ    0
# IQ     0
# dtype: int64

# %%
print("Valores duplicados: ", df.duplicated().sum())
# Out:
# Valores duplicados:  0

# %%
print(df.dtypes)
# Out:
# PIQ    float64
# IQ     float64
# dtype: object

# %% [markdown]
# Cambio de float a int

# %%
df = df[["IQ", "PIQ"]].astype('Int64')

# %% [markdown]
# Validacion de los datos transformados

# %%
print("\nValores nulos: ", df.isnull().sum())
print("\nValores duplicados: ", df.duplicated().sum())
print(df.dtypes)
df['IQ'] = df['IQ'] / 10
# Out:
# Valores nulos:  IQ     0
# PIQ    0
# dtype: int64
#
# Valores duplicados:  0
# IQ     Float64
# PIQ      Int64
# dtype: object

# %% [markdown]
# #4. Visualización de Datos

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='PIQ', y='IQ', data=df)
plt.title('Relación entre el tamaño del cerebro y el IQ')
plt.xlabel('Tamaño del cerebro)')
plt.ylabel('IQ')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['IQ'], kde=True)
plt.title('Distribución del CI')

plt.subplot(1, 2, 2)
sns.histplot(df['PIQ'], kde=True)
plt.title('Distribución del PIQ')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(y=df['PIQ'])
plt.title('Distribución de PIQ')
plt.ylabel('Puntuación PIQ')

plt.subplot(1, 2, 2)
sns.boxplot(y=df['IQ'])
plt.title('Distribución de IQ')
plt.ylabel('Puntuación IQ')

plt.tight_layout()
plt.show()

# %% [markdown]
# #5. Análisis e Interpretación

# %%
corr_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Existe una fuerte correlacion entre las variables

# %% [markdown]
# Se observa una relación positiva entre ambas variables, a medida que aumenta el PIQ, tiende a aumentar también el IQ. Esto sugiere que un mayor desempeño en habilidades específicas podría estar asociado con un IQ más alto.
